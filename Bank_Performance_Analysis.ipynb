# %% [markdown]
# <a href="https://colab.research.google.com/github/AndreiAf02/STAT561_Project/blob/main/Bank_Performance_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pymc as pm
import seaborn as sns
import pandas as pd

# %%
path_to_data = 'https://raw.githubusercontent.com/AndreiAf02/STAT561_Project/main/'

# %%
def perf_metrics(data, label):
    data_len = len(data)
    # print('Number of iterations:', data_len)
    mean = np.mean(data[label])
    var = np.var(data[label], ddof=1)
    var_mean = var/data_len

    se_mean = np.sqrt(var_mean)
    error_bound = 1.96*se_mean
    CI_low = mean - error_bound
    CI_high = mean + error_bound

    print('Error type:', label)
    print('Mean:', mean)
    print('Variance:', var)
    print('Variance of estimate:', var_mean)
    print('Standard error:', se_mean)
    print('95% Confidence Interval:  [', CI_low, ', ', CI_high, ']')
    print('-----------------------------')

# %% [markdown]
# Loading the performance data for the six sampling methods (plus original imbalanced data) collected from fine-tuning for heart disease prediction:

# %%
# data_orig = pd.read_csv("Credit_Imbalanced_Fine_Tuning.csv", sep=",", header=0)
# data_SRS = pd.read_csv("Credit_SRS_Fine_Tuning.csv", sep=",", header=0)
# data_SRSwR = pd.read_csv("Credit_SRSwR_Fine_Tuning.csv", sep=",", header=0)
# data_Sy = pd.read_csv("Credit_Sy_Fine_Tuning.csv", sep=",", header=0)
# data_Sym = pd.read_csv("Credit_Sy_multi_Fine_Tuning.csv", sep=",", header=0)
# data_SRS_ROS = pd.read_csv("Credit_SRS_ROS_Fine_Tuning.csv", sep=",", header=0)
# data_Sy_ROS = pd.read_csv("Credit_Sy_ROS_Fine_Tuning.csv", sep=",", header=0)

data_orig = pd.read_csv("Bank_Imbalanced_Fine_Tuning.csv", sep=",", header=0)
data_SRS = pd.read_csv("Bank_SRS_Fine_Tuning.csv", sep=",", header=0)
data_SRSwR = pd.read_csv("Bank_SRSwR_Fine_Tuning.csv", sep=",", header=0)
data_Sy = pd.read_csv("Bank_Sy_Fine_Tuning.csv", sep=",", header=0)
data_Sym = pd.read_csv("Bank_Sy_multi_Fine_Tuning.csv", sep=",", header=0)
data_SRS_ROS = pd.read_csv("Bank_SRS_ROS_Fine_Tuning.csv", sep=",", header=0)
data_Sy_ROS = pd.read_csv("Bank_Sy_ROS_Fine_Tuning.csv", sep=",", header=0)



# data_orig

# %% [markdown]
# Original (imbalanced) data performance:

# %%
data_orig
# Out:
#     Unnamed: 0  FPR  FNR
# 0            0  0.0  1.0
# 1            1  0.0  1.0
# 2            2  0.0  1.0
# 3            3  0.0  1.0
# 4            4  0.0  1.0
# 5            5  0.0  1.0
# 6            6  0.0  1.0
# 7            7  0.0  1.0
# 8            8  0.0  1.0
# 9            9  0.0  1.0
# 10          10  0.0  1.0
# 11          11  0.0  1.0
# 12          12  0.0  1.0
# 13          13  0.0  1.0
# 14          14  0.0  1.0
# 15          15  0.0  1.0
# 16          16  0.0  1.0
# 17          17  0.0  1.0
# 18          18  0.0  1.0
# 19          19  0.0  1.0
# 20          20  0.0  1.0
# 21          21  0.0  1.0
# 22          22  0.0  1.0
# 23          23  0.0  1.0
# 24          24  0.0  1.0
# 25          25  0.0  1.0
# 26          26  0.0  1.0
# 27          27  0.0  1.0
# 28          28  0.0  1.0
# 29          29  0.0  1.0
# 30          30  0.0  1.0
# 31          31  0.0  1.0
# 32          32  0.0  1.0
# 33          33  0.0  1.0
# 34          34  0.0  1.0
# 35          35  0.0  1.0
# 36          36  0.0  1.0
# 37          37  0.0  1.0
# 38          38  0.0  1.0
# 39          39  0.0  1.0
# 40          40  0.0  1.0
# 41          41  0.0  1.0
# 42          42  0.0  1.0
# 43          43  0.0  1.0
# 44          44  0.0  1.0
# 45          45  0.0  1.0
# 46          46  0.0  1.0
# 47          47  0.0  1.0
# 48          48  0.0  1.0
# 49          49  0.0  1.0

# %%
data = data_orig

orig_FPR = data['FPR']
orig_FNR = data['FNR']

fig = plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.hist(data['FPR'], color='g', bins=30, label='FPR', alpha=0.5)
plt.title('False Positive Rate')

plt.subplot(1, 2, 2)
plt.hist(data['FNR'], color='r', bins=30, label='FNR', alpha=0.5)
plt.title('False Negative Rate')
# plt.show()

perf_metrics(data, 'FPR')
perf_metrics(data, 'FNR')
# Out:
# Error type: FPR
# Mean: 0.0
# Variance: 0.0
# Variance of estimate: 0.0
# Standard error: 0.0
# 95% Confidence Interval:  [ 0.0 ,  0.0 ]
# -----------------------------
# Error type: FNR
# Mean: 1.0
# Variance: 0.0
# Variance of estimate: 0.0
# Standard error: 0.0
# 95% Confidence Interval:  [ 1.0 ,  1.0 ]
# -----------------------------

# %% [markdown]
# ## Random Undersampling (RUS):
#
# SRS Random Undersampling performance:

# %%
data = data_SRS

SRS_FPR = data['FPR']
SRS_FNR = data['FNR']

fig = plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.hist(data['FPR'], color='g', bins=30, label='FPR', alpha=0.5)
plt.title('False Positive Rate')

plt.subplot(1, 2, 2)
plt.hist(data['FNR'], color='r', bins=30, label='FNR', alpha=0.5)
plt.title('False Negative Rate')
# plt.show()

perf_metrics(data, 'FPR')
perf_metrics(data, 'FNR')
# Out:
# Error type: FPR
# Mean: 0.22997679814385152
# Variance: 0.00030831707399216955
# Variance of estimate: 6.166341479843391e-06
# Standard error: 0.0024832119280970345
# 95% Confidence Interval:  [ 0.22510970276478134 ,  0.2348438935229217 ]
# -----------------------------
# Error type: FNR
# Mean: 0.4114878892733563
# Variance: 0.0013013175960390265
# Variance of estimate: 2.602635192078053e-05
# Standard error: 0.005101602877604305
# 95% Confidence Interval:  [ 0.4014887476332518 ,  0.42148703091346074 ]
# -----------------------------

# %% [markdown]
# SRSwR undersampling performance:

# %%
data = data_SRSwR

SRSwR_FPR = data['FPR']
SRSwR_FNR = data['FNR']

fig = plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.hist(data['FPR'], color='g', bins=30, label='FPR', alpha=0.5)
plt.title('False Positive Rate')

plt.subplot(1, 2, 2)
plt.hist(data['FNR'], color='r', bins=30, label='FNR', alpha=0.5)
plt.title('False Negative Rate')
# plt.show()

perf_metrics(data, 'FPR')
perf_metrics(data, 'FNR')
# Out:
# Error type: FPR
# Mean: 0.19016241299303938
# Variance: 0.0011225659831279806
# Variance of estimate: 2.2451319662559612e-05
# Standard error: 0.004738282353612922
# 95% Confidence Interval:  [ 0.18087537957995806 ,  0.1994494464061207 ]
# -----------------------------
# Error type: FNR
# Mean: 0.501038062283737
# Variance: 0.00576318457364627
# Variance of estimate: 0.00011526369147292541
# Standard error: 0.010736092933321945
# 95% Confidence Interval:  [ 0.47999532013442603 ,  0.522080804433048 ]
# -----------------------------

# %% [markdown]
# Systematic Undersampling performance:

# %%
data = data_Sy

Sy_FPR = data['FPR']
Sy_FNR = data['FNR']

fig = plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.hist(data['FPR'], color='g', bins=30, label='FPR', alpha=0.5)
plt.title('False Positive Rate')

plt.subplot(1, 2, 2)
plt.hist(data['FNR'], color='r', bins=30, label='FNR', alpha=0.5)
plt.title('False Negative Rate')
# plt.show()

perf_metrics(data, 'FPR')
perf_metrics(data, 'FNR')
# Out:
# Error type: FPR
# Mean: 0.2149729311678267
# Variance: 0.0006444767171568967
# Variance of estimate: 1.2889534343137935e-05
# Standard error: 0.003590199763681394
# 95% Confidence Interval:  [ 0.20793613963101118 ,  0.22200972270464223 ]
# -----------------------------
# Error type: FNR
# Mean: 0.4359169550173011
# Variance: 0.0031684515858042784
# Variance of estimate: 6.336903171608556e-05
# Standard error: 0.00796046680264955
# 95% Confidence Interval:  [ 0.420314440084108 ,  0.4515194699504942 ]
# -----------------------------

# %% [markdown]
# Multiple Systematic undersampling performance:

# %%
data = data_Sym

Sym_FPR = data['FPR']
Sym_FNR = data['FNR']

fig = plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.hist(data['FPR'], color='g', bins=30, label='FPR', alpha=0.5)
plt.title('False Positive Rate')

plt.subplot(1, 2, 2)
plt.hist(data['FNR'], color='r', bins=30, label='FNR', alpha=0.5)
plt.title('False Negative Rate')
# plt.show()

perf_metrics(data, 'FPR')
perf_metrics(data, 'FNR')
# Out:
# Error type: FPR
# Mean: 0.10250580046403708
# Variance: 0.0018414955232078929
# Variance of estimate: 3.682991046415786e-05
# Standard error: 0.006068765151507995
# 95% Confidence Interval:  [ 0.09061102076708141 ,  0.11440058016099275 ]
# -----------------------------
# Error type: FNR
# Mean: 0.7591003460207613
# Variance: 0.0062000244836383596
# Variance of estimate: 0.00012400048967276718
# Standard error: 0.01113555071259465
# 95% Confidence Interval:  [ 0.7372746666240757 ,  0.7809260254174468 ]
# -----------------------------

# %% [markdown]
# ## Random Oversampling (ROS):
#
# SRS Oversampling performance:

# %%
data = data_SRS_ROS

SRS_ROS_FPR = data['FPR']
SRS_ROS_FNR = data['FNR']

fig = plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.hist(data['FPR'], color='g', bins=30, label='FPR', alpha=0.5)
plt.title('False Positive Rate')

plt.subplot(1, 2, 2)
plt.hist(data['FNR'], color='r', bins=30, label='FNR', alpha=0.5)
plt.title('False Negative Rate')
# plt.show()

perf_metrics(data, 'FPR')
perf_metrics(data, 'FNR')
# Out:
# Error type: FPR
# Mean: 0.16403712296983752
# Variance: 0.000462112088264587
# Variance of estimate: 9.24224176529174e-06
# Standard error: 0.0030401055516695043
# 95% Confidence Interval:  [ 0.1580785160885653 ,  0.16999572985110975 ]
# -----------------------------
# Error type: FNR
# Mean: 0.5211764705882352
# Variance: 0.0027664507691943065
# Variance of estimate: 5.532901538388613e-05
# Standard error: 0.007438347624565965
# 95% Confidence Interval:  [ 0.506597309244086 ,  0.5357556319323845 ]
# -----------------------------

# %% [markdown]
# Systematic Resampling performance:

# %%
data = data_Sy_ROS

Sy_ROS_FPR = data['FPR']
Sy_ROS_FNR = data['FNR']

fig = plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.hist(data['FPR'], color='g', bins=30, label='FPR', alpha=0.5)
plt.title('False Positive Rate')

plt.subplot(1, 2, 2)
plt.hist(data['FNR'], color='r', bins=30, label='FNR', alpha=0.5)
plt.title('False Negative Rate')
# plt.show()

perf_metrics(data, 'FPR')
perf_metrics(data, 'FNR')
# Out:
# Error type: FPR
# Mean: 0.1788553750966744
# Variance: 0.0014382904734793144
# Variance of estimate: 2.8765809469586287e-05
# Standard error: 0.005363376685408763
# 95% Confidence Interval:  [ 0.16834315679327322 ,  0.18936759340007558 ]
# -----------------------------
# Error type: FNR
# Mean: 0.5105190311418685
# Variance: 0.006275439954121279
# Variance of estimate: 0.0001255087990824256
# Standard error: 0.01120307096658883
# 95% Confidence Interval:  [ 0.48856101204735436 ,  0.5324770502363826 ]
# -----------------------------

# %%
FPR = pd.DataFrame()

DF = FPR

DF['Orig'] = orig_FPR
DF['SRS_RUS'] = SRS_FPR
DF['SRSwR_RUS'] = SRSwR_FPR
DF['Sy_RUS'] = Sy_FPR
DF['Sy_m_RUS'] = Sym_FPR
DF['SRS_ROS'] = SRS_ROS_FPR
DF['Sy_ROS'] = Sy_ROS_FPR

# %%
dataset = FPR

plt.figure(figsize=(4,6), dpi=600)
plt.title('FPR')
sns.boxplot([dataset['Orig'], dataset['SRS_RUS'], dataset['SRSwR_RUS'],
             dataset['Sy_RUS'], dataset['Sy_m_RUS'], dataset['SRS_ROS'], dataset['Sy_ROS']], orient='h')
# Out:
# <Axes: title={'center': 'FPR'}>

# %%
FNR = pd.DataFrame()

DF = FNR

DF['Orig'] = orig_FNR
DF['SRS_RUS'] = SRS_FNR
DF['SRSwR_RUS'] = SRSwR_FNR
DF['Sy_RUS'] = Sy_FNR
DF['Sy_m_RUS'] = Sym_FNR
DF['SRS_ROS'] = SRS_ROS_FNR
DF['Sy_ROS'] = Sy_ROS_FNR

# %%
dataset = FNR

plt.figure(figsize=(4,6), dpi=600)
plt.title('FNR')
sns.boxplot([dataset['Orig'], dataset['SRS_RUS'], dataset['SRSwR_RUS'],
             dataset['Sy_RUS'], dataset['Sy_m_RUS'], dataset['SRS_ROS'], dataset['Sy_ROS']], orient='h')
# Out:
# <Axes: title={'center': 'FNR'}>

# %% [markdown]
# ## Transductive TL performance:

# %%
# data_orig = pd.read_csv(path_to_data + "Imbalanced_Extended.csv", sep=",", header=0)
# data_SRS = pd.read_csv(path_to_data + "SRS_RUS_Extended.csv", sep=",", header=0)
# data_SRSwR = pd.read_csv(path_to_data + "SRSwR_RUS_Extended.csv", sep=",", header=0)
# data_Sy = pd.read_csv(path_to_data + "Sy_RUS_Extended.csv", sep=",", header=0)
# data_Sy2 = pd.read_csv(path_to_data + "Sy2_RUS_Extended.csv", sep=",", header=0)
# data_SRS_ROS = pd.read_csv(path_to_data + "SRS_ROS_Extended.csv", sep=",", header=0)
# data_Sy_ROS = pd.read_csv(path_to_data + "Sy_ROS_Extended.csv", sep=",", header=0)

data_orig = pd.read_csv("Bank_Imbalanced.csv", sep=",", header=0)
data_SRS = pd.read_csv("Bank_SRS_RUS.csv", sep=",", header=0)
data_SRSwR = pd.read_csv("Bank_SRSwR_RUS.csv", sep=",", header=0)
data_Sy = pd.read_csv("Bank_Sy_RUS.csv", sep=",", header=0)
data_Sy2 = pd.read_csv("Bank_Sy2_RUS.csv", sep=",", header=0)
data_SRS_ROS = pd.read_csv("Bank_SRS_ROS.csv", sep=",", header=0)
data_Sy_ROS = pd.read_csv("Bank_Sy_ROS.csv", sep=",", header=0)

data_SRS
# Out:
#     Unnamed: 0  Source time       FPR       TPR       FNR       TNR  \
# 0            0    12.596636  0.098841  0.748299  0.251701  0.901159
# 1            1    14.243331  0.104314  0.780612  0.219388  0.895686
# 2            2    10.008150  0.131681  0.824830  0.175170  0.868319
# 3            3    12.337391  0.174984  0.858844  0.141156  0.825016
# 4            4    11.148867  0.120412  0.802721  0.197279  0.879588
# 5            5    10.102469  0.144881  0.829932  0.170068  0.855119
# 6            6     9.872483  0.105280  0.787415  0.212585  0.894720
# 7            7     9.609812  0.154057  0.863946  0.136054  0.845943
# 8            8    10.674996  0.129910  0.819728  0.180272  0.870090
# 9            9     9.746573  0.138764  0.836735  0.163265  0.861236
# 10          10    10.834248  0.132325  0.833333  0.166667  0.867675
# 11          11     8.962771  0.108500  0.778912  0.221088  0.891500
# 12          12    10.685052  0.132003  0.831633  0.168367  0.867997
# 13          13    11.331186  0.127334  0.818027  0.181973  0.872666
# 14          14    14.119737  0.155023  0.852041  0.147959  0.844977
# 15          15    12.803549  0.183677  0.882653  0.117347  0.816323
# 16          16    12.618873  0.138603  0.819728  0.180272  0.861397
# 17          17    13.447143  0.117514  0.772109  0.227891  0.882486
# 18          18    12.800671  0.169189  0.865646  0.134354  0.830811
# 19          19    13.005647  0.104475  0.768707  0.231293  0.895525
# 20          20    12.602335  0.153896  0.841837  0.158163  0.846104
# 21          21    12.992606  0.085963  0.707483  0.292517  0.914037
# 22          22    12.543973  0.140534  0.843537  0.156463  0.859466
# 23          23    13.416470  0.125402  0.802721  0.197279  0.874598
# 24          24    13.994154  0.108661  0.770408  0.229592  0.891339
# 25          25    13.389635  0.092885  0.741497  0.258503  0.907115
# 26          26    12.854047  0.146008  0.846939  0.153061  0.853992
# 27          27    15.159459  0.153896  0.853741  0.146259  0.846104
# 28          28    13.705258  0.119285  0.806122  0.193878  0.880715
# 29          29    13.352710  0.120734  0.812925  0.187075  0.879266
# 30          30    12.596336  0.138281  0.841837  0.158163  0.861719
# 31          31    13.594555  0.140695  0.838435  0.161565  0.859305
# 32          32    13.624037  0.136027  0.811224  0.188776  0.863973
# 33          33    15.193904  0.108661  0.787415  0.212585  0.891339
# 34          34    12.642877  0.115422  0.799320  0.200680  0.884578
# 35          35    13.582226  0.216033  0.901361  0.098639  0.783967
# 36          36    15.512960  0.106407  0.765306  0.234694  0.893593
# 37          37    12.297438  0.117514  0.775510  0.224490  0.882486
# 38          38    13.895980  0.170476  0.867347  0.132653  0.829524
# 39          39    14.014607  0.121861  0.804422  0.195578  0.878139
# 40          40    13.515306  0.146169  0.853741  0.146259  0.853831
# 41          41    13.827050  0.113007  0.780612  0.219388  0.886993
# 42          42    16.918180  0.174823  0.875850  0.124150  0.825177
# 43          43    14.572947  0.147778  0.850340  0.149660  0.852222
# 44          44    13.199814  0.091919  0.729592  0.270408  0.908081
# 45          45    14.903779  0.112041  0.801020  0.198980  0.887959
# 46          46    13.550585  0.102222  0.773810  0.226190  0.897778
# 47          47    13.227743  0.132486  0.807823  0.192177  0.867514
# 48          48    13.745051  0.142144  0.857143  0.142857  0.857856
# 49          49    14.216118  0.163876  0.887755  0.112245  0.836124
#
#     Target time
# 0      0.764573
# 1      0.984185
# 2      0.772737
# 3      0.789927
# 4      0.767323
# 5      0.789148
# 6      0.785075
# 7      1.042168
# 8      1.046870
# 9      0.781416
# 10     0.974786
# 11     0.926622
# 12     0.801538
# 13     2.098105
# 14     1.242444
# 15     0.849381
# 16     0.832492
# 17     0.809592
# 18     1.048581
# 19     1.048000
# 20     1.048913
# 21     0.820797
# 22     0.837122
# 23     0.849727
# 24     1.309844
# 25     1.728026
# 26     1.067780
# 27     0.865157
# 28     0.889865
# 29     0.883950
# 30     0.861218
# 31     0.864351
# 32     0.900448
# 33     1.319392
# 34     1.736038
# 35     1.221511
# 36     1.080540
# 37     0.916513
# 38     1.118275
# 39     0.890734
# 40     1.073131
# 41     1.064059
# 42     1.483911
# 43     0.973985
# 44     1.076371
# 45     0.958240
# 46     0.957489
# 47     1.082573
# 48     1.087879
# 49     0.947568

# %% [markdown]
# Original (imbalanced) dataset:

# %%
print('SRS RUS', len(data_SRS))
print('SRSwR RUS', len(data_SRSwR))
print('Sy RUS', len(data_Sy))
print('Sym RUS', len(data_Sy2))
print('SRS ROS', len(data_SRS_ROS))
print('Sy ROS', len(data_Sy_ROS))
# Out:
# SRS RUS 50
# SRSwR RUS 50
# Sy RUS 50
# Sym RUS 50
# SRS ROS 50
# Sy ROS 50

# %%
orig_FPR = data_orig['FPR']
orig_FNR = data_orig['FNR']
orig_time = data_orig['Source time']

# %%
data = data_orig

fig = plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.hist(data['FPR'], color='g', bins=30, label='FPR', alpha=0.5)
plt.title('False Positive Rate')

plt.subplot(1, 2, 2)
plt.hist(data['FNR'], color='r', bins=30, label='FNR', alpha=0.5)
plt.title('False Negative Rate')
# plt.show()

perf_metrics(data, 'FPR')
perf_metrics(data, 'FNR')
perf_metrics(data, 'Source time')
# Out:
# Error type: FPR
# Mean: 0.02256922086284606
# Variance: 4.0373200771533656e-05
# Variance of estimate: 8.074640154306732e-07
# Standard error: 0.0008985900152075323
# 95% Confidence Interval:  [ 0.020807984433039297 ,  0.024330457292652822 ]
# -----------------------------
# Error type: FNR
# Mean: 0.6790476190476191
# Variance: 0.005121170222913545
# Variance of estimate: 0.00010242340445827089
# Standard error: 0.010120444874523593
# 95% Confidence Interval:  [ 0.6592115470935529 ,  0.6988836910016853 ]
# -----------------------------
# Error type: Source time
# Mean: 37.25087096371997
# Variance: 46.34164482833837
# Variance of estimate: 0.9268328965667674
# Standard error: 0.9627216090681497
# 95% Confidence Interval:  [ 35.36393660994639 ,  39.137805317493545 ]
# -----------------------------

# %% [markdown]
# ##Random Undersampling (RUS):
#
# SRS undersampling performance:

# %%
data = data_SRS

SRS_FPR = data['FPR']
SRS_FNR = data['FNR']
SRS_time = data['Source time']

fig = plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.hist(data['FPR'], color='g', bins=30, label='FPR', alpha=0.5)
plt.title('False Positive Rate')

plt.subplot(1, 2, 2)
plt.hist(data['FNR'], color='r', bins=30, label='FNR', alpha=0.5)
plt.title('False Negative Rate')
# plt.show()

perf_metrics(data, 'FPR')
perf_metrics(data, 'FNR')
perf_metrics(data, 'Source time')
# Out:
# Error type: FPR
# Mean: 0.13233741146168704
# Variance: 0.000699945474918772
# Variance of estimate: 1.3998909498375438e-05
# Standard error: 0.00374151165952686
# 95% Confidence Interval:  [ 0.1250040486090144 ,  0.13967077431435967 ]
# -----------------------------
# Error type: FNR
# Mean: 0.1837414965986394
# Variance: 0.0018337219658097871
# Variance of estimate: 3.667443931619574e-05
# Standard error: 0.0060559424795976835
# 95% Confidence Interval:  [ 0.17187184933862792 ,  0.19561114385865086 ]
# -----------------------------
# Error type: Source time
# Mean: 12.871834510459957
# Variance: 2.792197838366416
# Variance of estimate: 0.05584395676732832
# Standard error: 0.23631325982121343
# 95% Confidence Interval:  [ 12.408660521210379 ,  13.335008499709534 ]
# -----------------------------

# %% [markdown]
# SRSwR Undersampling performance:

# %%
data = data_SRSwR

SRSwR_FPR = data['FPR']
SRSwR_FNR = data['FNR']
SRSwR_time = data['Source time']

fig = plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.hist(data['FPR'], color='g', bins=30, label='FPR', alpha=0.5)
plt.title('False Positive Rate')

plt.subplot(1, 2, 2)
plt.hist(data['FNR'], color='r', bins=30, label='FNR', alpha=0.5)
plt.title('False Negative Rate')
# plt.show()

perf_metrics(data, 'FPR')
perf_metrics(data, 'FNR')
perf_metrics(data, 'Source time')
# Out:
# Error type: FPR
# Mean: 0.1278428847392144
# Variance: 0.00105318984840924
# Variance of estimate: 2.10637969681848e-05
# Standard error: 0.0045895312362140865
# 95% Confidence Interval:  [ 0.1188474035162348 ,  0.136838365962194 ]
# -----------------------------
# Error type: FNR
# Mean: 0.19744897959183672
# Variance: 0.003180393704059438
# Variance of estimate: 6.360787408118877e-05
# Standard error: 0.007975454474899142
# 95% Confidence Interval:  [ 0.1818170888210344 ,  0.21308087036263904 ]
# -----------------------------
# Error type: Source time
# Mean: 12.892521737859933
# Variance: 2.8920124908560902
# Variance of estimate: 0.057840249817121804
# Standard error: 0.24049999961979585
# 95% Confidence Interval:  [ 12.421141738605133 ,  13.363901737114734 ]
# -----------------------------

# %% [markdown]
# Systematic Undersampling performance:

# %%
data = data_Sy

Sy_FPR = data['FPR']
Sy_FNR = data['FNR']
Sy_time = data['Source time']

fig = plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.hist(data['FPR'], color='g', bins=30, label='FPR', alpha=0.5)
plt.title('False Positive Rate')

plt.subplot(1, 2, 2)
plt.hist(data['FNR'], color='r', bins=30, label='FNR', alpha=0.5)
plt.title('False Negative Rate')
# plt.show()

perf_metrics(data, 'FPR')
perf_metrics(data, 'FNR')
perf_metrics(data, 'Source time')
# Out:
# Error type: FPR
# Mean: 0.12907276239536378
# Variance: 0.0007046800022010747
# Variance of estimate: 1.4093600044021493e-05
# Standard error: 0.003754144382415452
# 95% Confidence Interval:  [ 0.1217146394058295 ,  0.13643088538489806 ]
# -----------------------------
# Error type: FNR
# Mean: 0.19336734693877544
# Variance: 0.0024412600664311256
# Variance of estimate: 4.882520132862251e-05
# Standard error: 0.006987503225660973
# 95% Confidence Interval:  [ 0.17967184061647992 ,  0.20706285326107096 ]
# -----------------------------
# Error type: Source time
# Mean: 12.79409699446007
# Variance: 4.485783800253851
# Variance of estimate: 0.08971567600507703
# Standard error: 0.2995257518229059
# 95% Confidence Interval:  [ 12.207026520887174 ,  13.381167468032965 ]
# -----------------------------

# %% [markdown]
# Multiple Systematic Undersampling performance:

# %%
data_Sy2
# Out:
#     Unnamed: 0  Source time       FPR       TNR       FNR       TPR  \
# 0            0     9.697337  0.132003  0.867997  0.212585  0.787415
# 1            1     8.793765  0.126529  0.873471  0.195578  0.804422
# 2            2     8.692254  0.106729  0.893271  0.250000  0.750000
# 3            3    10.768860  0.113812  0.886188  0.207483  0.792517
# 4            4     9.837659  0.133773  0.866227  0.171769  0.828231
# 5            5     9.566466  0.124759  0.875241  0.214286  0.785714
# 6            6    10.006104  0.099485  0.900515  0.255102  0.744898
# 7            7     9.978140  0.105602  0.894398  0.236395  0.763605
# 8            8    10.240593  0.118319  0.881681  0.232993  0.767007
# 9            9     9.032491  0.134900  0.865100  0.200680  0.799320
# 10          10     9.966257  0.107856  0.892144  0.209184  0.790816
# 11          11     9.166189  0.146008  0.853992  0.142857  0.857143
# 12          12    10.010896  0.128300  0.871700  0.197279  0.802721
# 13          13     9.902928  0.120090  0.879910  0.224490  0.775510
# 14          14    11.593970  0.109144  0.890856  0.221088  0.778912
# 15          15    11.312621  0.119768  0.880232  0.197279  0.802721
# 16          16    11.103592  0.136993  0.863007  0.181973  0.818027
# 17          17    11.622947  0.147135  0.852865  0.170068  0.829932
# 18          18    12.607313  0.092402  0.907598  0.260204  0.739796
# 19          19    16.671397  0.191082  0.808918  0.132653  0.867347
# 20          20    15.171651  0.068738  0.931262  0.377551  0.622449
# 21          21    14.675210  0.102704  0.897296  0.250000  0.750000
# 22          22    12.976645  0.157920  0.842080  0.153061  0.846939
# 23          23    13.506354  0.175789  0.824211  0.137755  0.862245
# 24          24    12.549735  0.153413  0.846587  0.142857  0.857143
# 25          25    14.401811  0.122505  0.877495  0.180272  0.819728
# 26          26    13.951107  0.119285  0.880715  0.215986  0.784014
# 27          27    14.063148  0.163715  0.836285  0.125850  0.874150
# 28          28    14.569498  0.125402  0.874598  0.202381  0.797619
# 29          29    11.306500  0.100129  0.899871  0.236395  0.763605
# 30          30    13.138912  0.124276  0.875724  0.197279  0.802721
# 31          31    14.535819  0.110753  0.889247  0.214286  0.785714
# 32          32    14.124380  0.103509  0.896491  0.243197  0.756803
# 33          33    13.358723  0.141983  0.858017  0.163265  0.836735
# 34          34    14.099929  0.116871  0.883129  0.222789  0.777211
# 35          35    14.251170  0.216838  0.783162  0.119048  0.880952
# 36          36    14.903968  0.103348  0.896652  0.251701  0.748299
# 37          37    13.330991  0.130071  0.869929  0.173469  0.826531
# 38          38    13.479382  0.124115  0.875885  0.207483  0.792517
# 39          39    13.322729  0.088699  0.911301  0.284014  0.715986
# 40          40    13.997148  0.193818  0.806182  0.119048  0.880952
# 41          41    14.169648  0.111880  0.888120  0.221088  0.778912
# 42          42    12.944771  0.127334  0.872666  0.209184  0.790816
# 43          43    13.237134  0.134256  0.865744  0.198980  0.801020
# 44          44    13.215842  0.134900  0.865100  0.188776  0.811224
# 45          45    13.017621  0.110592  0.889408  0.227891  0.772109
# 46          46    13.301207  0.089826  0.910174  0.306122  0.693878
# 47          47    12.714604  0.137315  0.862685  0.178571  0.821429
# 48          48    14.550537  0.132486  0.867514  0.193878  0.806122
# 49          49    13.552790  0.120412  0.879588  0.207483  0.792517
#
#     Target time
# 0      0.764860
# 1      1.023217
# 2      1.070577
# 3      0.761734
# 4      0.775658
# 5      1.047728
# 6      0.766891
# 7      1.038076
# 8      0.772186
# 9      1.138521
# 10     0.782154
# 11     1.033672
# 12     1.040718
# 13     0.820259
# 14     1.042358
# 15     0.812379
# 16     1.055079
# 17     1.071845
# 18     0.827865
# 19     1.074265
# 20     1.346087
# 21     1.339388
# 22     1.064357
# 23     1.068839
# 24     0.875405
# 25     1.084878
# 26     0.909537
# 27     0.915115
# 28     1.188597
# 29     1.345697
# 30     0.831786
# 31     1.056656
# 32     1.080788
# 33     0.904416
# 34     1.078776
# 35     1.263858
# 36     0.866523
# 37     1.079981
# 38     0.925474
# 39     1.047536
# 40     0.931073
# 41     0.917689
# 42     1.068395
# 43     0.908730
# 44     1.068825
# 45     0.935486
# 46     1.085985
# 47     0.906477
# 48     0.993638
# 49     1.903855

# %%
data = data_Sy2

Sy2_FPR = data['FPR']
Sy2_FNR = data['FNR']
Sy2_time = data['Source time']

fig = plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.hist(data['FPR'], color='g', bins=30, label='FPR', alpha=0.5)
plt.title('False Positive Rate')

plt.subplot(1, 2, 2)
plt.hist(data['FNR'], color='r', bins=30, label='FNR', alpha=0.5)
plt.title('False Negative Rate')
# plt.show()

perf_metrics(data, 'FPR')
perf_metrics(data, 'FNR')
perf_metrics(data, 'Source time')
# Out:
# Error type: FPR
# Mean: 0.1267514488087572
# Variance: 0.0007559941499919598
# Variance of estimate: 1.5119882999839195e-05
# Standard error: 0.0038884293744183133
# 95% Confidence Interval:  [ 0.1191301272348973 ,  0.13437277038261708 ]
# -----------------------------
# Error type: FNR
# Mean: 0.2052721088435374
# Variance: 0.0023105747227392965
# Variance of estimate: 4.621149445478593e-05
# Standard error: 0.006797903680899423
# 95% Confidence Interval:  [ 0.19194821762897452 ,  0.21859600005810026 ]
# -----------------------------
# Error type: Source time
# Mean: 12.419814865759909
# Variance: 4.044919670729796
# Variance of estimate: 0.08089839341459593
# Standard error: 0.28442642882579655
# 95% Confidence Interval:  [ 11.862339065261347 ,  12.97729066625847 ]
# -----------------------------

# %% [markdown]
# ## Random Oversampling (ROS):
#
# SRS Oversampling performance:

# %%
data = data_SRS_ROS

SRS_ROS_FPR = data['FPR']
SRS_ROS_FNR = data['FNR']
SRS_ROS_time = data['Source time']

fig = plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.hist(data['FPR'], color='g', bins=30, label='FPR', alpha=0.5)
plt.title('False Positive Rate')

plt.subplot(1, 2, 2)
plt.hist(data['FNR'], color='r', bins=30, label='FNR', alpha=0.5)
plt.title('False Negative Rate')
# plt.show()

perf_metrics(data, 'FPR')
perf_metrics(data, 'FNR')
perf_metrics(data, 'Source time')
# Out:
# Error type: FPR
# Mean: 0.14755312298776557
# Variance: 0.0005485075344537089
# Variance of estimate: 1.0970150689074178e-05
# Standard error: 0.0033121217805319567
# 95% Confidence Interval:  [ 0.14106136429792293 ,  0.15404488167760821 ]
# -----------------------------
# Error type: FNR
# Mean: 0.13312925170068024
# Variance: 0.0012921014581037198
# Variance of estimate: 2.5842029162074395e-05
# Standard error: 0.005083505597722343
# 95% Confidence Interval:  [ 0.12316558072914445 ,  0.14309292267221604 ]
# -----------------------------
# Error type: Source time
# Mean: 62.46242834995992
# Variance: 188.47009359835312
# Variance of estimate: 3.7694018719670623
# Standard error: 1.941494751980304
# 95% Confidence Interval:  [ 58.65709863607852 ,  66.26775806384131 ]
# -----------------------------

# %% [markdown]
# Systematic Resampling performance:

# %%
data_Sy_ROS
# Out:
#     Unnamed: 0  Source time       FPR       TNR       FNR       TPR  \
# 0            0    50.025062  0.192531  0.807469  0.091837  0.908163
# 1            1    50.876569  0.169672  0.830328  0.095238  0.904762
# 2            2    55.105255  0.124115  0.875885  0.164966  0.835034
# 3            3    48.945116  0.159208  0.840792  0.122449  0.877551
# 4            4    44.156225  0.154057  0.845943  0.132653  0.867347
# 5            5    47.169476  0.166613  0.833387  0.090136  0.909864
# 6            6    50.905640  0.149549  0.850451  0.096939  0.903061
# 7            7    58.505166  0.133451  0.866549  0.149660  0.850340
# 8            8    46.168284  0.138925  0.861075  0.125850  0.874150
# 9            9    47.922635  0.115100  0.884900  0.139456  0.860544
# 10          10    49.470060  0.132968  0.867032  0.170068  0.829932
# 11          11    45.316720  0.132164  0.867836  0.139456  0.860544
# 12          12    49.937392  0.189150  0.810850  0.090136  0.909864
# 13          13    53.732784  0.171925  0.828075  0.088435  0.911565
# 14          14    48.419464  0.140212  0.859788  0.161565  0.838435
# 15          15    59.980933  0.203638  0.796362  0.088435  0.911565
# 16          16    55.423820  0.181423  0.818577  0.088435  0.911565
# 17          17    49.154805  0.153091  0.846909  0.110544  0.889456
# 18          18    60.735525  0.118641  0.881359  0.170068  0.829932
# 19          19    56.773005  0.137315  0.862685  0.147959  0.852041
# 20          20    57.194014  0.109305  0.890695  0.198980  0.801020
# 21          21    68.065019  0.129427  0.870573  0.134354  0.865646
# 22          22    65.120354  0.096909  0.903091  0.231293  0.768707
# 23          23    71.184058  0.155666  0.844334  0.115646  0.884354
# 24          24    84.344806  0.147778  0.852222  0.117347  0.882653
# 25          25    76.817462  0.146813  0.853187  0.141156  0.858844
# 26          26    72.885214  0.173696  0.826304  0.095238  0.904762
# 27          27    72.230213  0.165808  0.834192  0.108844  0.891156
# 28          28    67.769450  0.160979  0.839021  0.100340  0.899660
# 29          29    84.153548  0.126368  0.873632  0.170068  0.829932
# 30          30    70.235755  0.166130  0.833870  0.108844  0.891156
# 31          31    74.975752  0.164037  0.835963  0.093537  0.906463
# 32          32    80.772486  0.133934  0.866066  0.159864  0.840136
# 33          33    72.391707  0.120090  0.879910  0.175170  0.824830
# 34          34    65.775059  0.146491  0.853509  0.130952  0.869048
# 35          35    75.501907  0.115583  0.884417  0.209184  0.790816
# 36          36    71.222780  0.136349  0.863651  0.144558  0.855442
# 37          37    67.541462  0.138442  0.861558  0.132653  0.867347
# 38          38    85.252729  0.114456  0.885544  0.185374  0.814626
# 39          39    75.994464  0.133451  0.866549  0.147959  0.852041
# 40          40    72.066260  0.170959  0.829041  0.100340  0.899660
# 41          41    80.456788  0.188828  0.811172  0.073129  0.926871
# 42          42    82.407499  0.155827  0.844173  0.122449  0.877551
# 43          43    73.652088  0.150515  0.849485  0.122449  0.877551
# 44          44    73.932014  0.172569  0.827431  0.090136  0.909864
# 45          45    91.733657  0.140373  0.859627  0.146259  0.853741
# 46          46    81.497738  0.172086  0.827914  0.085034  0.914966
# 47          47    69.335952  0.129749  0.870251  0.151361  0.848639
# 48          48    81.197423  0.122827  0.877173  0.159864  0.840136
# 49          49    94.993276  0.150354  0.849646  0.132653  0.867347
#
#     Target time
# 0      0.784797
# 1      2.514232
# 2      0.802183
# 3      0.802815
# 4      1.077493
# 5      0.799817
# 6      0.806244
# 7      0.798201
# 8      1.259662
# 9      1.227315
# 10     1.055023
# 11     1.061331
# 12     0.845603
# 13     0.810903
# 14     0.835586
# 15     1.057941
# 16     1.058076
# 17     1.065820
# 18     0.846349
# 19     1.231466
# 20     0.840811
# 21     1.073832
# 22     1.087971
# 23     0.896194
# 24     0.905262
# 25     1.747566
# 26     0.947464
# 27     0.919740
# 28     1.082910
# 29     0.872310
# 30     1.071418
# 31     1.739667
# 32     1.279738
# 33     1.121856
# 34     1.252288
# 35     0.871624
# 36     1.937148
# 37     1.275696
# 38     0.964856
# 39     0.945695
# 40     1.293744
# 41     1.267885
# 42     1.060478
# 43     1.145879
# 44     1.249057
# 45     1.062490
# 46     1.075769
# 47     0.974727
# 48     0.942968
# 49     1.076872

# %%
data = data_Sy_ROS

Sy_ROS_FPR = data['FPR']
Sy_ROS_FNR = data['FNR']
Sy_ROS_time = data['Source time']

fig = plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.hist(data['FPR'], color='g', bins=30, label='FPR', alpha=0.5)
plt.title('False Positive Rate')

plt.subplot(1, 2, 2)
plt.hist(data['FNR'], color='r', bins=30, label='FNR', alpha=0.5)
plt.title('False Negative Rate')
# plt.show()

perf_metrics(data, 'FPR')
perf_metrics(data, 'FNR')
perf_metrics(data, 'Source time')
# Out:
# Error type: FPR
# Mean: 0.14799098518995488
# Variance: 0.0005655298997726671
# Variance of estimate: 1.1310597995453343e-05
# Standard error: 0.0033631232501134035
# 95% Confidence Interval:  [ 0.1413992636197326 ,  0.15458270676017716 ]
# -----------------------------
# Error type: FNR
# Mean: 0.13098639455782307
# Variance: 0.001276807613229938
# Variance of estimate: 2.553615226459876e-05
# Standard error: 0.005053330808941639
# 95% Confidence Interval:  [ 0.12108186617229746 ,  0.14089092294334868 ]
# -----------------------------
# Error type: Source time
# Mean: 65.78849734123978
# Variance: 188.6123910298122
# Variance of estimate: 3.7722478205962435
# Standard error: 1.942227540891191
# 95% Confidence Interval:  [ 61.98173136109304 ,  69.59526332138651 ]
# -----------------------------

# %%
FPR = pd.DataFrame()

DF = FPR

DF['Orig'] = orig_FPR
DF['SRS_RUS'] = SRS_FPR
DF['SRSwR_RUS'] = SRSwR_FPR
DF['Sy_RUS'] = Sy_FPR
DF['Sy_m_RUS'] = Sy2_FPR
DF['SRS_ROS'] = SRS_ROS_FPR
DF['Sy_ROS'] = Sy_ROS_FPR

# %%
dataset = FPR

plt.figure(figsize=(4,6), dpi=600)
plt.title('FPR')
sns.boxplot([dataset['Orig'], dataset['SRS_RUS'], dataset['SRSwR_RUS'],
             dataset['Sy_RUS'], dataset['Sy_m_RUS'], dataset['SRS_ROS'], dataset['Sy_ROS']], orient='h')
# Out:
# <Axes: title={'center': 'FPR'}>

# %%
FNR = pd.DataFrame()

DF = FNR

DF['Orig'] = orig_FNR
DF['SRS_RUS'] = SRS_FNR
DF['SRSwR_RUS'] = SRSwR_FNR
DF['Sy_RUS'] = Sy_FNR
DF['Sy_m_RUS'] = Sy2_FNR
DF['SRS_ROS'] = SRS_ROS_FNR
DF['Sy_ROS'] = Sy_ROS_FNR

# %%
dataset = FNR

plt.figure(figsize=(4,6), dpi=600)
plt.title('FNR')
sns.boxplot([dataset['Orig'], dataset['SRS_RUS'], dataset['SRSwR_RUS'],
             dataset['Sy_RUS'], dataset['Sy_m_RUS'], dataset['SRS_ROS'], dataset['Sy_ROS']], orient='h')
# Out:
# <Axes: title={'center': 'FNR'}>

# %%
Time = pd.DataFrame()

DF = FNR

DF['Orig'] = orig_time
DF['SRS_RUS'] = SRS_time
DF['SRSwR_RUS'] = SRSwR_time
DF['Sy_RUS'] = Sy_time
DF['Sy_m_RUS'] = Sy2_time
DF['SRS_ROS'] = SRS_ROS_time
DF['Sy_ROS'] = Sy_ROS_time

# %%
dataset = DF

plt.figure(figsize=(4,6), dpi=600)
plt.title('Training Time')
sns.boxplot([dataset['Orig'], dataset['SRS_RUS'], dataset['SRSwR_RUS'],
             dataset['Sy_RUS'], dataset['Sy_m_RUS'], dataset['SRS_ROS'], dataset['Sy_ROS']], orient='h')
# Out:
# <Axes: title={'center': 'Training Time'}>
